# %% [markdown]
# # 1D-CNN for Text

# %%
import numpy as np

# %%
X = np.random.randn(1, 300, 10)
W = np.random.randn(16, 300, 3)

# %%
def forward_pass(X, W, batch):
    slice_0 = X[:, 0:2]
    mul = slice_0 * W
    out_0 = np.sum(mul)
